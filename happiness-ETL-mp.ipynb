# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df_2015 = pd.read_csv('data_source/2015.csv')
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_2016 = pd.read_csv('data_source/2016.csv')
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df_2017 = pd.read_csv('data_source/2017.csv')
df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df_2018_org = pd.read_csv('data_source/2018.csv')
df_2018_org.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
df_2019_org = pd.read_csv('data_source/2019.csv')
df_2019_org.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
year = 2015
df_2015 = df_2015.assign(Year = year)
df_2015.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
# Rename the columns in the df_2015 DataFrame.
#df_2015 = df_2015.rename({'Economy (GDP per Capita)':'Economy..GDP.per.Capita.','Health (Life Expectancy)':'Health..Life.Expectancy', 'Perception of Corruption in Government':'Trust..Government.Corruption.'}, axis='columns')

# %%
df_2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df_2015.columns.tolist()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual',
#  'Year']

# %%
#df.drop(['B', 'C'], axis=1)
df_2015 = df_2015.drop(['Region','Standard Error','Dystopia Residual'], axis=1)

# %%
df_2015.columns.tolist()
# Out:
# ['Country',
#  'Happiness Rank',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Year']

# %%
#df = df[['x','z','y','q','p']]
#df
# pandas.DataFrame.reindex(columns=column_names)
#df.columns = ['x','y','z','p','q']

# %%
df_2015.rename(columns={'Trust (Government Corruption)':'Perceptions of Corruption'},inplace=True)

# %%
df_2015.columns.tolist()
# Out:
# ['Country',
#  'Happiness Rank',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Perceptions of Corruption',
#  'Generosity',
#  'Year']

# %%
# pandas.DataFrame.reindex(columns=column_names)
#p = p.reindex(columns=['1Sun', '2Mon', '3Tue', '4Wed', '5Thu', '6Fri', '7Sat'])

# %%
#reorder collummns
#df.columns = ['x','y','z','p','q']
df_2015.columns = ['Country',
 'Happiness Rank',
 'Happiness Score',
 'Economy (GDP per Capita)',
 'Family',
 'Health (Life Expectancy)',
 'Freedom',
 'Perceptions of Corruption',
 'Generosity',
 'Year']

#df_2015 = df_2015.reindex(columns = Year, Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family','Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity)
#df_2015

# %%
#df = df[['x','z','y','q','p']]
df_2015 = df_2015[['Year','Country','Happiness Rank','Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Perceptions of Corruption','Generosity']]
df_2015
# Out:
#      Year      Country  Happiness Rank  Happiness Score  \
# 0    2015  Switzerland               1            7.587
# 1    2015      Iceland               2            7.561
# 2    2015      Denmark               3            7.527
# 3    2015       Norway               4            7.522
# 4    2015       Canada               5            7.427
# ..    ...          ...             ...              ...
# 153  2015       Rwanda             154            3.465
# 154  2015        Benin             155            3.340
# 155  2015        Syria             156            3.006
# 156  2015      Burundi             157            2.905
# 157  2015         Togo             158            2.839
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# ...

# %%
df_2015.columns.tolist()
# Out:
# ['Year',
#  'Country',
#  'Happiness Rank',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Perceptions of Corruption',
#  'Generosity']

# %%
#2016

# %%
year = 2016
df_2016=df_2016.assign(Year = year)
df_2016.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df_2016 = df_2016.drop(['Region', 'Lower Confidence Interval','Upper Confidence Interval', 'Dystopia Residual'], axis=1)

# %%
df_2016.columns.tolist()
# Out:
# ['Country',
#  'Happiness Rank',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Year']

# %%
df_2016.rename(columns={'Trust (Government Corruption)':'Perceptions of Corruption'},inplace=True)

# %%
df_2016.columns.tolist()
# Out:
# ['Country',
#  'Happiness Rank',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Perceptions of Corruption',
#  'Generosity',
#  'Year']

# %%
#reorder columsn  Use this code for reordering
df_2016 = df_2016.reindex(columns = ['Year','Country','Happiness Rank','Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Percentions of Corruption','Generosity'])
df_2016
# Out:
#      Year      Country  Happiness Rank  Happiness Score  \
# 0    2016      Denmark               1            7.526
# 1    2016  Switzerland               2            7.509
# 2    2016      Iceland               3            7.501
# 3    2016       Norway               4            7.498
# 4    2016      Finland               5            7.413
# ..    ...          ...             ...              ...
# 152  2016        Benin             153            3.484
# 153  2016  Afghanistan             154            3.360
# 154  2016         Togo             155            3.303
# 155  2016        Syria             156            3.069
# 156  2016      Burundi             157            2.905
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.44178  1.16374                   0.79504  0.57941
# 1                     1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df_2016.columns.tolist()
# Out:
# ['Year',
#  'Country',
#  'Happiness Rank',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Percentions of Corruption',
#  'Generosity']

# %%
#2017

# %%
year = 2017
df_2017=df_2017.assign(Year = year)
df_2017.head(5)
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual  Year
# ...

# %%
df_2017.columns.tolist()
# Out:
# ['Country',
#  'Happiness.Rank',
#  'Happiness.Score',
#  'Whisker.high',
#  'Whisker.low',
#  'Economy..GDP.per.Capita.',
#  'Family',
#  'Health..Life.Expectancy.',
#  'Freedom',
#  'Generosity',
#  'Trust..Government.Corruption.',
#  'Dystopia.Residual',
#  'Year']

# %%
#df_2017 = df_2017.drop(columns={'Whisker.high','Whisker.low','Dystopia Residual'}, axis='columns', inplace=True)

df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual  Year
# ...

# %%
#droping columns
df_2017 = df_2017.drop(['Whisker.high','Whisker.low','Dystopia.Residual'], axis=1)
df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Economy..GDP.per.Capita.  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#      Family  Health..Life.Expectancy.   Freedom  Generosity  \
# 0  1.533524                  0.796667  0.635423    0.362012
# 1  1.551122                  0.792566  0.626007    0.355280
# 2  1.610574                  0.833552  0.627163    0.475540
# 3  1.516912                  0.858131  0.620071    0.290549
# 4  1.540247                  0.809158  0.617951    0.245483
#
#    Trust..Government.Corruption.  Year
# 0                       0.315964  2017
# 1                       0.400770  2017
# ...

# %%
df_2017.columns.tolist()
# Out:
# ['Country',
#  'Happiness.Rank',
#  'Happiness.Score',
#  'Economy..GDP.per.Capita.',
#  'Family',
#  'Health..Life.Expectancy.',
#  'Freedom',
#  'Generosity',
#  'Trust..Government.Corruption.',
#  'Year']

# %%
df_2017 = df_2017.rename(columns = {"Trust..Government.Corruption.":"Perceptions of Corruption",
                                    "Happiness.Rank":"Happiness Rank",
                                   "Happiness.Score":"Happiness Score",
                                   "Economy..GDP.per.Capita.":"Economy (GDP per Capita)",
                                   "Health..Life.Expectancy.":"Health (Life Expectancy)"})
df_2017.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#      Family  Health (Life Expectancy)   Freedom  Generosity  \
# 0  1.533524                  0.796667  0.635423    0.362012
# 1  1.551122                  0.792566  0.626007    0.355280
# 2  1.610574                  0.833552  0.627163    0.475540
# 3  1.516912                  0.858131  0.620071    0.290549
# 4  1.540247                  0.809158  0.617951    0.245483
#
#    Perceptions of Corruption  Year
# 0                   0.315964  2017
# 1                   0.400770  2017
# 2                   0.153527  2017
# ...

# %%
#reordering columsn
df_2017 = df_2017[['Year','Country','Happiness Rank','Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Perceptions of Corruption','Generosity']]
df_2017
# Out:
#      Year                   Country  Happiness Rank  Happiness Score  \
# 0    2017                    Norway               1            7.537
# 1    2017                   Denmark               2            7.522
# 2    2017                   Iceland               3            7.504
# 3    2017               Switzerland               4            7.494
# 4    2017                   Finland               5            7.469
# ..    ...                       ...             ...              ...
# 150  2017                    Rwanda             151            3.471
# 151  2017                     Syria             152            3.462
# 152  2017                  Tanzania             153            3.349
# 153  2017                   Burundi             154            2.905
# 154  2017  Central African Republic             155            2.693
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# ...

# %%
#2018

# %%
year = 2018
df_2018=df_2018_org.assign(Year = year)
df_2018.head(5)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption  Year
# 0                      0.393  2018
# 1                      0.340  2018
# ...

# %%
df_2018.columns.tolist()
# Out:
# ['Overall rank',
#  'Country or region',
#  'Score',
#  'GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption',
#  'Year']

# %%
#df_2018 = df_2018.rename(columns={'':'', '':'', '':''}, inplace=True)
#df.rename(columns={'z':'new_z','d':'new_d'},inplace=True)
df_2018_update = df_2018.rename({'Social support':'Family','Overall rank':'Happiness Rank','Score':'Happiness Score','Country or region':'Country','GDP per capita':'Economy (GDP per Capita)','Perceptions of corruption':'Perceptions of Corruption', 'Healthy life expectancy':'Health (Life Expectancy)', 'Freedom to make life choices': 'Freedom'},axis=1)
df_2018_update.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.632                     1.305
# 1               2       Norway            7.594                     1.456
# 2               3      Denmark            7.555                     1.351
# 3               4      Iceland            7.495                     1.343
# 4               5  Switzerland            7.487                     1.420
#
#    Family  Health (Life Expectancy)  Freedom  Generosity  \
# 0   1.592                     0.874    0.681       0.202
# 1   1.582                     0.861    0.686       0.286
# 2   1.590                     0.868    0.683       0.284
# 3   1.644                     0.914    0.677       0.353
# 4   1.549                     0.927    0.660       0.256
#
#    Perceptions of Corruption  Year
# 0                      0.393  2018
# 1                      0.340  2018
# 2                      0.408  2018
# ...

# %%
df_2018_update.columns.tolist()
# Out:
# ['Happiness Rank',
#  'Country',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Generosity',
#  'Perceptions of Corruption',
#  'Year']

# %%
df_2018 = df_2018_update[['Year','Country','Happiness Rank','Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Perceptions of Corruption','Generosity']]
df_2018
# Out:
#      Year                   Country  Happiness Rank  Happiness Score  \
# 0    2018                   Finland               1            7.632
# 1    2018                    Norway               2            7.594
# 2    2018                   Denmark               3            7.555
# 3    2018                   Iceland               4            7.495
# 4    2018               Switzerland               5            7.487
# ..    ...                       ...             ...              ...
# 151  2018                     Yemen             152            3.355
# 152  2018                  Tanzania             153            3.303
# 153  2018               South Sudan             154            3.254
# 154  2018  Central African Republic             155            3.083
# 155  2018                   Burundi             156            2.905
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
year = 2019
df_2019=df_2019_org.assign(Year = year)
df_2019.head(5)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption  Year
# 0                      0.393  2019
# 1                      0.410  2019
# ...

# %%
df_2019.columns.tolist()
# Out:
# ['Overall rank',
#  'Country or region',
#  'Score',
#  'GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption',
#  'Year']

# %%
df_2019_update = df_2019.rename({'Social support':'Family','Overall rank':'Happiness Rank','Score':'Happiness Score','Country or region':'Country','GDP per capita':'Economy (GDP per Capita)','Perceptions of corruption':'Perceptions of Corruption', 'Healthy life expectancy':'Health (Life Expectancy)', 'Freedom to make life choices': 'Freedom'},axis=1)
df_2019_update.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.769                     1.340
# 1               2      Denmark            7.600                     1.383
# 2               3       Norway            7.554                     1.488
# 3               4      Iceland            7.494                     1.380
# 4               5  Netherlands            7.488                     1.396
#
#    Family  Health (Life Expectancy)  Freedom  Generosity  \
# 0   1.587                     0.986    0.596       0.153
# 1   1.573                     0.996    0.592       0.252
# 2   1.582                     1.028    0.603       0.271
# 3   1.624                     1.026    0.591       0.354
# 4   1.522                     0.999    0.557       0.322
#
#    Perceptions of Corruption  Year
# 0                      0.393  2019
# 1                      0.410  2019
# 2                      0.341  2019
# ...

# %%
df_2019 = df_2019_update[['Year','Country','Happiness Rank','Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Perceptions of Corruption','Generosity']]
df_2019
# Out:
#      Year                   Country  Happiness Rank  Happiness Score  \
# 0    2019                   Finland               1            7.769
# 1    2019                   Denmark               2            7.600
# 2    2019                    Norway               3            7.554
# 3    2019                   Iceland               4            7.494
# 4    2019               Netherlands               5            7.488
# ..    ...                       ...             ...              ...
# 151  2019                    Rwanda             152            3.334
# 152  2019                  Tanzania             153            3.231
# 153  2019               Afghanistan             154            3.203
# 154  2019  Central African Republic             155            3.083
# 155  2019               South Sudan             156            2.853
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df_2016.shape

# %%
df_2017.shape

# %%
df_2018.shape

# %%
df_2019.shape

# %%
### join 2015, 2016, 2018, 2019 to one data frame for use in Tableau visualization
data = pd.concat([df_2015, df_2016, df_2017, df_2018, df_2019], ignore_index=True)
data = data.iloc[:, :-1]
#data[data['Year']==2019]
data.tail()
# Out:
#      Year                   Country  Happiness Rank  Happiness Score  \
# 777  2019                    Rwanda             152            3.334
# 778  2019                  Tanzania             153            3.231
# 779  2019               Afghanistan             154            3.203
# 780  2019  Central African Republic             155            3.083
# 781  2019               South Sudan             156            2.853
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 777                     0.359   0.711                     0.614    0.555
# 778                     0.476   0.885                     0.499    0.417
# 779                     0.350   0.517                     0.361    0.000
# 780                     0.026   0.000                     0.105    0.225
# 781                     0.306   0.575                     0.295    0.010
#
#      Perceptions of Corruption  Generosity
# 777                      0.411       0.217
# ...

# %%
len(data)
# Out:
# 782

# %%
total = len(df_2015)+len(df_2016)+len(df_2017)+len(df_2018)+len(df_2019)
total
# Out:
# 782

# %%
final_data = data.rename({'Family':'Social Support'},axis=1)
final_data.head()
# Out:
#    Year      Country  Happiness Rank  Happiness Score  \
# 0  2015  Switzerland               1            7.587
# 1  2015      Iceland               2            7.561
# 2  2015      Denmark               3            7.527
# 3  2015       Norway               4            7.522
# 4  2015       Canada               5            7.427
#
#    Economy (GDP per Capita)  Social Support  Health (Life Expectancy)  \
# 0                   1.39651         1.34951                   0.94143
# 1                   1.30232         1.40223                   0.94784
# 2                   1.32548         1.36058                   0.87464
# 3                   1.45900         1.33095                   0.88521
# 4                   1.32629         1.32261                   0.90563
#
#    Freedom  Perceptions of Corruption  Generosity
# 0  0.66557                    0.41978     0.29678
# 1  0.62877                    0.14145     0.43630
# 2  0.64938                    0.48357     0.34139
# ...

# %%
# Create output file #creates excel file each run.  run only once
final_data.to_excel("Total 2015 to 2019 Data.xlsx")

# %%
#total_df = pd.concat([df_2015, df_2016,df_2017,df_2018,df_2019])
#total_df.columns = ['Country', 'Score', 'Year']
#total_df = total_df.merge(ISO_df, how='left')

# %%
#df3 = df1.merge(df2, on='A', how='inner', suffixes=('_1', '_2')) #2015 to 2016
df_1516 = df_2015.merge(df_2016, on="Country") #2015-2016
df_1516.head

# %%
#df3 = df1.merge(df2, on='A', how='inner', suffixes=('_1', '_2'))v
#df_1517 = df_1516.merge(df_2017, on="Country") #df1 = 1516 df2 = 2017  #2015 to 2017
df_1517 = df_1516.merge(df_2017, on="Country")
df_1517.head(5)

# %%
#2015 to 2018
df_1518 = df_1517.merge(df_2018, on="Country")
df_1518.head(5)

# %%
#2019 to 2018
df_1519 = df_1518.merge(df_2019, on="Country")
df_1519.head(5)

# %%
df_1519.shape

# %%
total_df = df_1519
total_df.head(5)

# %%
##df3 = df1.merge(df2, on='A', how='inner', suffixes=('_1', '_2'))

# %%
pd.set_option('display.max_columns', None)

# %%
total_df

# %%
#df.to_csv(r'Path where you want to store the exported CSV file\File Name.csv')

# %%
total_df.to_csv(r'C:\Users\mildred\world-happiness-analysis\total_df.csv')

# %%
#Linear Regression

# %%
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from sklearn.linear_model import LinearRegression

# %%
plt.scatter(df_2015.Economy, df_2015.Score)
plt.xlabel('Economy')
plt.ylabel('Score')
plt.show()

# %%
# Split dependent and independent variables
X = df_2015.Economy.values.reshape(-1, 1)
X.shape

# %%
y = df_2015.Score

# %%
# Build Linear Regression model 
model = LinearRegression()
model.fit(X, y)

# %%
# Prediction
y_pred = model.predict(X)
print(y_pred.shape)

# %%
# Plot predictions 
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel('Economy')
plt.ylabel('Score')
plt.show()

# print slope of line
print(model.coef_)
